# %% [markdown]
# # Imports and Config

# %%
import os
import pickle

import matplotlib.pyplot as plt
import numpy as np
import opensim as osim
import yaml
from scipy.signal import find_peaks

from grf_pipeline_utils.data_utils import (
    ad2float,
    exclude_segments,
    filter_segments,
    flatten_to_muscle_dict,
    get_all_segments,
    interp_segments,
    normalize_by_mass_in_order,
    plot_muscle_grid,
)

repo_root = os.path.abspath('../')
with open(os.path.join(repo_root, 'config.yaml')) as f:
    cfg = yaml.safe_load(f)

data_dir      = os.path.join(repo_root, cfg['uhlrich']['data_root'])
processed_dir = os.path.join(repo_root, cfg['paths']['processed_dir'], 'Uhlrich')
_uv_major = cfg['active']['uhlrich_version'].split('.')[0]
out_path      = os.path.join(processed_dir, f'Uhlrich_segs_v{_uv_major}_normalized_filtered')

subject_ids = cfg['uhlrich']['subject_ids']
trial_names = cfg['uhlrich']['trial_names']
subj_masses = cfg['uhlrich']['masses']

# %% [markdown]
# # Setup

# %%
# Full muscle set matching OA_BatchProcessing
muscles = [
    'addbrev_r', 'addlong_r', 'addmagDist_r', 'addmagIsch_r', 'addmagMid_r', 'addmagProx_r',
    'bflh_r', 'bfsh_r', 'edl_r', 'ehl_r', 'fdl_r', 'fhl_r', 'gaslat_r', 'gasmed_r',
    'glmax1_r', 'glmax2_r', 'glmax3_r', 'glmed1_r', 'glmed2_r', 'glmed3_r',
    'glmin1_r', 'glmin2_r', 'glmin3_r', 'grac_r', 'iliacus_r', 'perbrev_r', 'perlong_r',
    'psoas_r', 'recfem_r', 'semimem_r', 'semiten_r', 'soleus_r',
    'tibant_r', 'tibpost_r', 'vasint_r', 'vaslat_r', 'vasmed_r',

    'addbrev_l', 'addlong_l', 'addmagDist_l', 'addmagIsch_l', 'addmagMid_l', 'addmagProx_l',
    'bflh_l', 'bfsh_l', 'edl_l', 'ehl_l', 'fdl_l', 'fhl_l', 'gaslat_l', 'gasmed_l',
    'glmax1_l', 'glmax2_l', 'glmax3_l', 'glmed1_l', 'glmed2_l', 'glmed3_l',
    'glmin1_l', 'glmin2_l', 'glmin3_l', 'grac_l', 'iliacus_l', 'perbrev_l', 'perlong_l',
    'psoas_l', 'recfem_l', 'semimem_l', 'semiten_l', 'soleus_l',
    'tibant_l', 'tibpost_l', 'vasint_l', 'vaslat_l', 'vasmed_l'
]
base_muscles = sorted({m[:-2] for m in muscles if m.endswith(('_r', '_l'))})
base_muscles.append('achilles')
print(f'{len(base_muscles)} muscles (including achilles): {base_muscles}')

jrf_cols = {
    'hip_fx': ('hip_r_on_femur_r_in_femur_r_fx', 'hip_l_on_femur_l_in_femur_l_fx'),
    'hip_fy': ('hip_r_on_femur_r_in_femur_r_fy', 'hip_l_on_femur_l_in_femur_l_fy'),
    'hip_fz': ('hip_r_on_femur_r_in_femur_r_fz', 'hip_l_on_femur_l_in_femur_l_fz'),
    'knee_fx': ('walker_knee_r_on_tibia_r_in_tibia_r_fx', 'walker_knee_l_on_tibia_l_in_tibia_l_fx'),
    'knee_fy': ('walker_knee_r_on_tibia_r_in_tibia_r_fy', 'walker_knee_l_on_tibia_l_in_tibia_l_fy'),
    'knee_fz': ('walker_knee_r_on_tibia_r_in_tibia_r_fz', 'walker_knee_l_on_tibia_l_in_tibia_l_fz'),
    'ankle_fx': ('ankle_r_on_talus_r_in_talus_r_fx', 'ankle_l_on_talus_l_in_talus_l_fx'),
    'ankle_fy': ('ankle_r_on_talus_r_in_talus_r_fy', 'ankle_l_on_talus_l_in_talus_l_fy'),
    'ankle_fz': ('ankle_r_on_talus_r_in_talus_r_fz', 'ankle_l_on_talus_l_in_talus_l_fz'),
}
# Out:
# 38 muscles (including achilles): ['addbrev', 'addlong', 'addmagDist', 'addmagIsch', 'addmagMid', 'addmagProx', 'bflh', 'bfsh', 'edl', 'ehl', 'fdl', 'fhl', 'gaslat', 'gasmed', 'glmax1', 'glmax2', 'glmax3', 'glmed1', 'glmed2', 'glmed3', 'glmin1', 'glmin2', 'glmin3', 'grac', 'iliacus', 'perbrev', 'perlong', 'psoas', 'recfem', 'semimem', 'semiten', 'soleus', 'tibant', 'tibpost', 'vasint', 'vaslat', 'vasmed', 'achilles']

# %% [markdown]
# # Extract Gait Segments
#
# Load GRF `.mot` and Static Optimization `results_forces.sto` for each subject and trial.
# Segments are detected from zero-crossings in the vertical GRF, then filtered by threshold checks
# to remove missteps. Both right and left limbs are included; the medial-lateral GRF is sign-flipped
# for left contacts.

# %%
for sid in subject_ids:
    subj_key = f'Subject{sid}'
    for trial in trial_names:
        grf_path    = os.path.join(data_dir, subj_key, cfg['uhlrich']['subject_structure']['raw_grf'], f'{trial}_forces.mot')
        muscle_path = os.path.join(data_dir, subj_key, cfg['uhlrich']['subject_structure']['so'], trial, 'results_forces.sto')
        jrf_path    = os.path.join(data_dir, subj_key, cfg['uhlrich']['subject_structure']['so'], trial, 'results_JointReaction_JointRxn_ReactionLoads.sto')
        print('GRF:', grf_path)
        print('MUS:', muscle_path)
        print('JRF:', jrf_path)
        print('GRF exists:', os.path.exists(jrf_path))
        break
    break
# Out:
# GRF: /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_baseline1_forces.mot
# MUS: /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_baseline1/results_forces.sto
# JRF: /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto
# GRF exists: True

# %%
def load_muscle_side(storage, base_muscle_names, side):
    """Return {base_name: np.array} for one side ('r' or 'l')."""
    out = {}
    for m in base_muscle_names:
        col = osim.ArrayDouble()
        storage.getDataColumn(f'{m}_{side}', col)
        out[m] = ad2float(col)
    return out


compiled_segs = {}
base_no_achilles = [m for m in base_muscles if m != 'achilles']

for sid in subject_ids:
    subj_key = f'Subject{sid}'
    compiled_segs[subj_key] = {
        'grf_x': [], 'grf_y': [], 'grf_z': [],
        'cop_x': [], 'cop_z': [],
        **{m: [] for m in base_muscles},
        **{k: [] for k in jrf_cols}
    }
    subj_data = compiled_segs[subj_key]

    for trial in trial_names:
        grf_path    = os.path.join(data_dir, subj_key, cfg['uhlrich']['subject_structure']['raw_grf'], f'{trial}_forces.mot')
        muscle_path = os.path.join(data_dir, subj_key, cfg['uhlrich']['subject_structure']['so'], trial, 'results_forces.sto')
        jrf_path    = os.path.join(data_dir, subj_key, cfg['uhlrich']['subject_structure']['so'], trial, 'results_JointReaction_JointRxn_ReactionLoads.sto')

        if not os.path.exists(grf_path) or not os.path.exists(muscle_path) or not os.path.exists(jrf_path):
            print(f'  Missing: {subj_key}/{trial} — skipping')
            continue

        if not os.path.exists(grf_path) or not os.path.exists(muscle_path):
            print(f'  Missing: {subj_key}/{trial} — skipping')
            continue

        grf_storage    = osim.Storage(grf_path)
        muscle_storage = osim.Storage(muscle_path)
        jrf_storage = osim.Storage(jrf_path)

        # --- time ---
        time_col = osim.ArrayDouble()
        grf_storage.getTimeColumn(time_col)
        time_arr = ad2float(time_col)

        # --- GRF right ---
        def _load_grf(storage, col_name):
            c = osim.ArrayDouble()
            storage.getDataColumn(col_name, c)
            return ad2float(c)
        
        def _load_jrf(storage, col_name):
            c = osim.ArrayDouble()
            storage.getDataColumn(col_name, c)
            return ad2float(c)

        grf_x_r = _load_grf(grf_storage, 'ground_force_vx')
        grf_y_r = _load_grf(grf_storage, 'ground_force_vy')
        grf_z_r = _load_grf(grf_storage, 'ground_force_vz')
        cop_x_r = _load_grf(grf_storage, 'ground_force_px')
        cop_z_r = _load_grf(grf_storage, 'ground_force_pz')

        # --- GRF left ---
        grf_x_l = _load_grf(grf_storage, '1_ground_force_vx')
        grf_y_l = _load_grf(grf_storage, '1_ground_force_vy')
        grf_z_l = _load_grf(grf_storage, '1_ground_force_vz')
        cop_x_l = _load_grf(grf_storage, '1_ground_force_px')
        cop_z_l = _load_grf(grf_storage, '1_ground_force_pz')

        # --- muscles ---
        mdata_r = load_muscle_side(muscle_storage, base_no_achilles, 'r')
        mdata_l = load_muscle_side(muscle_storage, base_no_achilles, 'l')

        # --- joint contact forces ---
        jrf_r = {k: _load_jrf(jrf_storage, cols[0]) for k, cols in jrf_cols.items()}
        jrf_l = {k: _load_jrf(jrf_storage, cols[1]) for k, cols in jrf_cols.items()}

        # --- detect stance phases from GRF zero-crossings ---
        for side in ('r', 'l'):
            grf_y = grf_y_r if side == 'r' else grf_y_l
            grf_x = grf_x_r if side == 'r' else grf_x_l
            grf_z = grf_z_r if side == 'r' else grf_z_l
            cop_x = cop_x_r if side == 'r' else cop_x_l
            cop_z = cop_z_r if side == 'r' else cop_z_l
            mdata  = mdata_r  if side == 'r' else mdata_l
            jrf_data = jrf_r if side == 'r' else jrf_l
            z_sign = 1.0      if side == 'r' else -1.0

            crossings = np.where(np.diff(grf_y > 0) == 1)[0] + 1
            if grf_y[0] > 0:
                crossings = crossings[1:]
            n_segs = len(crossings) // 2

            for j in range(n_segs):
                s_idx = crossings[2 * j] - 1
                e_idx = crossings[2 * j + 1] + 1

                grf_y_seg = grf_y[s_idx:e_idx]
                grf_x_seg = grf_x[s_idx:e_idx]
                grf_z_seg = z_sign * grf_z[s_idx:e_idx]

                # misstep filter
                idx10 = int(len(grf_y_seg) * 0.10)
                idx30 = int(len(grf_y_seg) * 0.30)
                idx80 = int(len(grf_y_seg) * 0.80)
                if grf_y_seg[idx10] < 100 or grf_y_seg[idx80] < 300 or grf_y_seg[idx30] < 475:
                    continue

                # COP with forward-progression correction
                cop_x_seg = np.zeros_like(grf_y_seg)
                cop_z_seg = np.zeros_like(grf_y_seg)
                peak_idxs, _ = find_peaks(grf_y_seg,
                                          height=0.5 * np.max(grf_y_seg),
                                          distance=int(0.2 * 50))
                if peak_idxs.size >= 2:
                    pk1, pk2 = peak_idxs[0], peak_idxs[1]
                    t_seg = time_arr[pk1:pk2] - time_arr[pk1]
                    cop_corr = t_seg * 1.25
                    cx = cop_x[s_idx:e_idx]
                    cop_x_seg[pk1:pk2] = cx[pk1:pk2] - cx[pk1] + cop_corr
                    cz = cop_z[s_idx:e_idx]
                    cop_z_seg[pk1:pk2] = z_sign * (cz[pk1:pk2] - cz[pk1])

                # ehl sanity check (kept from original)
                ehl_seg = mdata['ehl'][s_idx:e_idx]
                if ehl_seg.max() > 100:
                    continue

                subj_data['grf_x'].append(grf_x_seg)
                subj_data['grf_y'].append(grf_y_seg)
                subj_data['grf_z'].append(grf_z_seg)
                subj_data['cop_x'].append(cop_x_seg)
                subj_data['cop_z'].append(cop_z_seg)

                for m in base_no_achilles:
                    subj_data[m].append(mdata[m][s_idx:e_idx])

                for k in jrf_cols:
                    seg = jrf_data[k][s_idx:e_idx]
                    if k.endswith('_fz'):
                        seg = z_sign * seg
                    subj_data[k].append(seg)

                subj_data['achilles'].append(
                    mdata['gaslat'][s_idx:e_idx] +
                    mdata['gasmed'][s_idx:e_idx] +
                    mdata['soleus'][s_idx:e_idx]
                )

    n = len(subj_data['grf_y'])
    print(f'{subj_key}: {n} segments')

total = sum(len(v['grf_y']) for v in compiled_segs.values())
print(f'\nTotal: {total} segments')
# Out:
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=121120 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_baseline1/results_forces.sto (nr=3028 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3028 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=122200 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3055 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3055 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=121160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3029 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3029 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=115840 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=2896 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2896 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=119280 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=2982 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2982 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=114680 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=2867 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2867 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=119480 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=2987 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2987 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/ExpmtlData/GRF/walking_retention1_forces.mot (nr=679640 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_retention1/results_forces.sto (nr=16991 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject1/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=16991 nc=127)
# Subject1: 1359 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=171720 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_baseline1/results_forces.sto (nr=4293 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=4293 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=120360 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3009 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3009 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=119200 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=2980 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2980 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=121000 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3025 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3025 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=119360 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=2984 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2984 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=122160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3054 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3054 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=121000 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3025 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3025 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/ExpmtlData/GRF/walking_retention1_forces.mot (nr=761800 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_retention1/results_forces.sto (nr=19045 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject2/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=19045 nc=127)
# Subject2: 1517 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=197280 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_baseline1/results_forces.sto (nr=4932 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=4932 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=127560 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3189 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3189 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=119760 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=2994 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2994 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=131960 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3299 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3299 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=120920 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=3023 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3023 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=128760 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3219 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3219 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=120400 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3010 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3010 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/ExpmtlData/GRF/walking_retention1_forces.mot (nr=752080 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_retention1/results_forces.sto (nr=18802 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject3/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18802 nc=127)
# Subject3: 1526 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=190480 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_baseline1/results_forces.sto (nr=4762 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=4762 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=130200 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3255 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3255 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=123720 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3093 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3093 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=124600 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3115 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3115 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=121400 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=3035 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3035 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=121440 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3036 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3036 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=120440 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3011 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3011 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/ExpmtlData/GRF/walking_retention1_forces.mot (nr=726840 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_retention1/results_forces.sto (nr=18171 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject4/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18171 nc=127)
# Subject4: 1338 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=194200 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_baseline1/results_forces.sto (nr=4855 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=4855 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=120160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3004 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3004 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=120160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3004 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3004 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=119640 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=2991 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2991 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=120200 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=3005 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3005 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=119920 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=2998 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2998 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=120360 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3009 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3009 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/ExpmtlData/GRF/walking_retention1_forces.mot (nr=727040 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_retention1/results_forces.sto (nr=18176 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject5/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18176 nc=127)
# Subject5: 1482 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=249760 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_baseline1/results_forces.sto (nr=6244 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=6244 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=119920 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=2998 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2998 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=119960 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=2999 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2999 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=120200 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3005 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3005 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=119720 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=2993 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2993 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=119920 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=2998 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2998 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=129800 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3245 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3245 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/ExpmtlData/GRF/walking_retention1_forces.mot (nr=798080 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_retention1/results_forces.sto (nr=19952 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject6/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=19952 nc=127)
# Subject6: 1545 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=195000 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_baseline1/results_forces.sto (nr=4875 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=4875 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=120160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3004 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3004 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=120040 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3001 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3001 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=120280 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3007 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3007 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=119880 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=2997 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2997 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=120160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3004 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3004 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=137880 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3447 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3447 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/ExpmtlData/GRF/walking_retention1_forces.mot (nr=751120 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_retention1/results_forces.sto (nr=18778 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject7/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18778 nc=127)
# Subject7: 1541 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=200400 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_baseline1/results_forces.sto (nr=5010 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=5010 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=122400 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3060 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3060 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=124320 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3108 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3108 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=121080 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3027 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3027 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=120560 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=3014 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3014 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=120400 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3010 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3010 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=120640 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3016 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3016 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/ExpmtlData/GRF/walking_retention1_forces.mot (nr=728640 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_retention1/results_forces.sto (nr=18216 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject8/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18216 nc=127)
# Subject8: 1581 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=161440 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_baseline1/results_forces.sto (nr=4036 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=4036 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=139560 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3489 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3489 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=120440 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3011 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3011 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=121920 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3048 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3048 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=120800 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=3020 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3020 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=120680 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3017 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3017 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=120680 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=3017 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3017 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/ExpmtlData/GRF/walking_retention1_forces.mot (nr=743760 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_retention1/results_forces.sto (nr=18594 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject9/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18594 nc=127)
# Subject9: 1450 segments
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_baseline1_forces.mot (nr=143480 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_baseline1/results_forces.sto (nr=3587 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_baseline1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3587 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_FBexp1_finalNoFB1_forces.mot (nr=120640 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBexp1_finalNoFB1/results_forces.sto (nr=3016 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBexp1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3016 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_FBexp1_finalFB1_forces.mot (nr=120640 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBexp1_finalFB1/results_forces.sto (nr=3016 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBexp1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3016 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_FBcolor1_finalNoFB1_forces.mot (nr=120880 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor1_finalNoFB1/results_forces.sto (nr=3022 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor1_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3022 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_FBcolor1_finalFB1_forces.mot (nr=120360 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor1_finalFB1/results_forces.sto (nr=3009 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor1_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3009 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_FBcolor2_finalNoFB1_forces.mot (nr=120800 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor2_finalNoFB1/results_forces.sto (nr=3020 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor2_finalNoFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=3020 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_FBcolor2_finalFB1_forces.mot (nr=119880 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor2_finalFB1/results_forces.sto (nr=2997 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_FBcolor2_finalFB1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=2997 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/ExpmtlData/GRF/walking_retention1_forces.mot (nr=739160 nc=19)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_retention1/results_forces.sto (nr=18479 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMusclePrediction/data/Uhlrich_Data/Subject10/StaticOpt/walking_retention1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=18479 nc=127)
# Subject10: 1558 segments
#
# Total: 14897 segments

# %% [markdown]
# # Length-Based Exclusion
#
# Drop segments whose raw sample count falls outside [20, 70]

# %%
all_keys = ['grf_x', 'grf_y', 'grf_z', 'cop_x', 'cop_z'] + base_muscles + list(jrf_cols.keys())

for subj, data in compiled_segs.items():
    for key in all_keys:
        data[key] = exclude_segments(data[key], 20, 70)

total = sum(len(v['grf_y']) for v in compiled_segs.values())
print(f'{total} segments after length filter')
# Out:
# 14892 segments after length filter

# %% [markdown]
# # Resample to 100 Points

# %%
n_interp_points = 100
resampled_segs = {}

for subj, subj_data in compiled_segs.items():
    resampled_segs[subj] = {}
    for key, seg_list in subj_data.items():
        if len(seg_list) == 0:
            resampled_segs[subj][key] = []
            continue
        resampled, time_resampled = interp_segments(seg_list, n_interp_points)
        resampled_segs[subj][key] = resampled

resampled_segs['time_resampled'] = time_resampled

total = sum(len(v.get('grf_y', [])) for v in resampled_segs.values() if isinstance(v, dict))
print(f'{total} segments after resampling')
# Out:
# 14892 segments after resampling

# %% [markdown]
# # Normalize by Body Mass (N → N/kg)

# %%
normalizer_keys = base_muscles + ['grf_x', 'grf_y', 'grf_z', 'hip_fx', 'hip_fy', 'hip_fz', 'knee_fx', 'knee_fy', 'knee_fz', 'ankle_fx', 'ankle_fy', 'ankle_fz']

normalized_segs = normalize_by_mass_in_order(resampled_segs, subj_masses, normalizer_keys)

# %% [markdown]
# # MAD / % Outside Filter
#
# Drop segments where:
# - RMS of excess beyond the ±2.5 std band exceeds `rms_threshold`, **or**
# - More than `mean_threshold` fraction of timepoints fall outside ±2 std of the population mean

# %%
from collections import Counter

consistency_mode = 'any'
rms_threshold    = 1.5
mean_threshold   = 1

filter_keys = base_muscles +  ['knee_fy', 'ankle_fy', 'hip_fy', 'grf_x', 'grf_y', 'grf_z', 'cop_x']

normalized_segs_filtered, dropped, bands = filter_segments(
    seg_dict=normalized_segs,
    muscle_keys=filter_keys,
    consistency_mode=consistency_mode,
    rms_threshold=rms_threshold,
    mean_threshold=mean_threshold,
)

n_before = sum(len(d.get('achilles', [])) for d in normalized_segs.values() if isinstance(d, dict))
n_after  = sum(len(d.get('achilles', [])) for d in normalized_segs_filtered.values() if isinstance(d, dict))
print(f'Segments before: {n_before}')
print(f'Segments after : {n_after}')
print(f'Dropped        : {len(dropped)} ({100*len(dropped)/n_before:.1f}%)')


c = Counter()
for _, _, bad in dropped:
    c.update(bad)
print('\nTop muscles triggering drops:')
for muscle, count in c.most_common(10):
    print(f'  {muscle:<20} {count}')

# %% [markdown]
# # Plot Inputs

# %%
grf_y_resampled = get_all_segments(normalized_segs_filtered, 'grf_y')
grf_x_resampled = get_all_segments(normalized_segs_filtered, 'grf_x')
grf_z_resampled = get_all_segments(normalized_segs_filtered, 'grf_z')
cop_x_resampled = get_all_segments(normalized_segs_filtered, 'cop_x')
cop_z_resampled = get_all_segments(normalized_segs_filtered, 'cop_z')
time_resampled  = normalized_segs_filtered['time_resampled']
t = time_resampled[0] * 100

fig, axes = plt.subplots(2, 3, figsize=(15, 9), sharex=True)

grf_components = [('Vertical (N/kg)', grf_y_resampled), ('Anterior-Posterior (N/kg)', grf_x_resampled), ('Medial-Lateral (N/kg)', grf_z_resampled)]
for ax, (label, arr) in zip(axes[0], grf_components):
    for seg in arr:
        ax.plot(t, seg, color='#A2C7E7', linewidth=1.5, alpha=0.4)
    ax.plot(t, np.mean(arr, axis=0), color='#1A5EB6', linewidth=3)
    ax.set_title(label, fontsize=14)
    ax.tick_params(labelsize=13)
axes[0][0].set_ylabel('GRF', fontsize=14)

cop_components = [('COP X (m)', cop_x_resampled), ('COP Z (m)', cop_z_resampled)]
for ax, (label, arr) in zip(axes[1], cop_components):
    for seg in arr:
        ax.plot(t, seg, color='#A2E7C7', linewidth=1.5, alpha=0.4)
    ax.plot(t, np.mean(arr, axis=0), color='#1AB66A', linewidth=3)
    ax.set_title(label, fontsize=14)
    ax.set_xlabel('Percent Stance (%)', fontsize=14)
    ax.tick_params(labelsize=13)
axes[1][0].set_ylabel('COP', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot Filtered Muscle Forces

# %%
resampled_filtered_muscles = flatten_to_muscle_dict(normalized_segs_filtered, base_muscles)

plot_muscle_grid(
    resampled_filtered_muscles,
    time_resampled,
    base_muscles,
    plot_mean=True
)

# %% [markdown]
# # Plot Joint Contact Forces

# %%
jrf_plot_keys = ['hip_fx', 'hip_fy', 'hip_fz', 'knee_fx', 'knee_fy', 'knee_fz', 'ankle_fx', 'ankle_fy', 'ankle_fz']
jrf_labels    = ['Hip FX', 'Hip FY', 'Hip FZ', 'Knee FX', 'Knee FY', 'Knee FZ', 'Ankle FX', 'Ankle FY', 'Ankle FZ']

fig, axes = plt.subplots(3, 3, figsize=(15, 12), sharex=True)
axes = axes.flatten()

for ax, key, label in zip(axes, jrf_plot_keys, jrf_labels):
    arr = get_all_segments(normalized_segs_filtered, key)
    for seg in arr:
        ax.plot(t, seg, color='#C7A2E7', linewidth=1.5, alpha=0.4)
    ax.plot(t, np.mean(arr, axis=0), color='#6A1AB6', linewidth=3)
    ax.set_title(label, fontsize=16)
    ax.set_xlabel('Percent Stance (%)', fontsize=14)
    ax.tick_params(labelsize=13)

axes[0].set_ylabel('Force (N/kg)', fontsize=14)
axes[3].set_ylabel('Force (N/kg)', fontsize=14)
axes[6].set_ylabel('Force (N/kg)', fontsize=14)
plt.suptitle('Joint Reaction Forces', fontsize=18, y=1.02)
plt.tight_layout()
plt.show()

# %%
subj_keys = [k for k in normalized_segs_filtered if isinstance(k, str) and k != 'time_resampled']
signal_keys = [k for k in next(v for v in normalized_segs_filtered.values() if isinstance(v, dict))]

print(f"{'='*65}")
print(f"  Ulrich filtered segments  ({len(subj_keys)} subjects)")
print(f"{'='*65}")

total = 0
for subj in sorted(subj_keys, key=lambda s: int(s.replace('Subject', ''))):
    data = normalized_segs_filtered[subj]
    n = len(data.get('grf_y', []))
    total += n
    print(f"\n  {subj}  —  {n} segments")
    print(f"    signals ({len(signal_keys)}): {', '.join(sorted(signal_keys))}")

print(f"\n{'='*65}")
print(f"  Total segments : {total}")
print(f"  Total signals  : {len(signal_keys)}")
print(f"  Signal length  : {normalized_segs_filtered['time_resampled'][0].shape[0]} points")

# %% [markdown]
# # Export

# %%
with open(out_path, 'wb') as f:
    pickle.dump(normalized_segs_filtered, f)
print(f'Saved {n_after} segments → {out_path}')
