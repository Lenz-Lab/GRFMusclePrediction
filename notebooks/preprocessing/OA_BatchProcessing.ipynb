# %%
import os
import matplotlib.pyplot as plt
from grf_pipeline_utils.signal_processing import *
from grf_pipeline_utils.opensim_utils import *
from grf_pipeline_utils.data_utils import *
import pickle

# %% [markdown]
# # Import all segmented gait data
#
# Load the pre-computed `all_segs` dictionary from disk. `all_segs` is a nested structure keyed by subject ID, where each subject maps trial names to a dict of `'left'` and `'right'` lists of `(start_time, end_time)` tuples identifying individual stance-phase gait cycles detected during preprocessing. The following cell counts the total number of left and right foot contacts across all subjects and trials.

# %%
root_dir = '/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/'
with open(root_dir + 'all_segs.pkl', 'rb') as f:
    all_segs = pickle.load(f)
print(all_segs)
#import dictionary of gait cycles with unrealistic muscle activations
with open(root_dir + 'problematic_activation_segs', 'rb') as f:
    problematic_activation_segs = pickle.load(f)
print(problematic_activation_segs)
problem_seg_keys = set(
    (
        d["subject"],
        d["side"].lower(),
        round(d["start_time"], 4),
        round(d["end_time"], 4),
    )
    for d in problematic_activation_segs
)
# Out:
# {'OA1': {'OA1_80_1': {'left': [(1.2885, 2.0735)], 'right': [(0.6945, 1.475), (1.886, 2.696)]}, 'OA1_80_2': {'left': [(1.207, 2.011)], 'right': [(0.6065, 1.4145), (1.824, 2.6345)]}, 'OA1_80_3': {'left': [(1.151, 1.9685)], 'right': [(0.543, 1.357), (1.778, 2.577)]}, 'OA1_80_4': {'left': [(1.232, 2.0545)], 'right': [(0.624, 1.433), (1.8555, 2.689)]}, 'OA1_80_5': {'left': [(1.0405, 1.837)], 'right': [(0.4395, 1.2235), (1.652, 2.4615)]}, 'OA1_100_1': {'left': [(0.912, 1.6125)], 'right': [(0.37, 1.072), (1.4565, 2.1605)]}, 'OA1_100_2': {'left': [(1.0515, 1.741)], 'right': [(0.5325, 1.214), (1.5905, 2.278)]}, 'OA1_100_3': {'left': [(0.978, 1.6435)], 'right': [(0.476, 1.1395), (1.502, 2.178)]}, 'OA1_100_4': {'left': [(0.551, 1.1595), (1.5375, 2.1985)], 'right': [(1.0135, 1.698)]}, 'OA1_100_5': {'left': [(0.8995, 1.5655)], 'right': [(0.385, 1.061), (1.418, 2.1145)]}, 'OA1_120_1': {'left': [(0.9025, 1.513)], 'right': [(0.409, 1.0285)]}, 'OA1_120_2': {'left': [(0.7965, 1.4055)], 'right': [(0.347, 0.9285), (1.2845, 1.9045)]}, 'OA1_120_3': {'left': [(0.679, 1.2935)], 'right': [(0.1845, 0.8095), (1.1695, 1.744)]}, 'OA1_120_4': {'left': [(0.8915, 1.501)], 'right': [(0.444, 1.0285), (1.3805, 1.98)]}, 'OA1_120_5': {'left': [(0.2715, 0.8885), (1.2495, 1.874)], 'right': [(0.757, 1.3845)]}}, 'OA2': {'OA2_80_1': {'left': [(1.308, 2.086)], 'right': [(0.713, 1.486), (1.908, 2.668)]}, 'OA2_80_2': {'left': [(0.173, 0.9215), (1.339, 2.1235)], 'right': [(0.753, 1.5215)]}, 'OA2_80_3': {'left': [(0.547, 1.332), (1.7645, 2.5475)], 'right': [(1.153, 1.946)]}, 'OA2_80_4': {'left': [(0.325, 1.111), (1.5305, 2.321)], 'right': [(0.9305, 1.726)]}, 'OA2_80_5': {'left': [(0.2615, 1.0555), (1.492, 2.3185)], 'right': [(0.8615, 1.6765)]}, 'OA2_100_1': {'left': [(0.809, 1.4855)], 'right': [(0.2815, 0.9545), (1.337, 2.0225)]}, 'OA2_100_2': {'left': [(0.8135, 1.4615)], 'right': [(0.291, 0.946), (1.3065, 1.9495)]}, 'OA2_100_3': {'left': [(0.8485, 1.5045)], 'right': [(0.3385, 0.9815), (1.357, 2.028)]}, 'OA2_100_4': {'left': [(0.736, 1.3735)], 'right': [(0.232, 0.8705), (1.2315, 1.882)]}, 'OA2_100_5': {'left': [(0.963, 1.6115)], 'right': [(0.4415, 1.1035), (1.4615, 2.1135)]}, 'OA2_120_1': {'left': [(1.114, 1.7065)], 'right': [(0.64, 1.225)]}, 'OA2_120_2': {'left': [(0.7325, 1.3095)], 'right': [(0.256, 0.8345)]}, 'OA2_120_3': {'left': [(0.8145, 1.404)], 'right': [(0.346, 0.9255), (1.2945, 1.884)]}, 'OA2_120_4': {'left': [(0.7515, 1.348)], 'right': [(0.3035, 0.8635), (1.2105, 1.81)]}, 'OA2_120_5': {'left': [(0.745, 1.3435)], 'right': [(0.2935, 0.8565), (1.2205, 1.8215)]}}, 'OA4': {'OA4_80_1': {'left': [(0.9885, 1.773), (2.158, 2.9585)], 'right': [(1.5965, 2.349)]}, 'OA4_80_2': {'left': [(0.75, 1.5505), (2.0095, 2.9675)], 'right': [(1.3705, 2.185)]}, 'OA4_80_3': {'left': [(0.921, 1.7545), (2.1885, 3.0305)], 'right': [(1.5595, 2.4105)]}, 'OA4_80_4': {'left': [(1.031, 1.8065), (2.2195, 3.0375)], 'right': [(1.619, 2.413)]}, 'OA4_80_5': {'left': [(1.183, 2.009), (2.438, 3.313)], 'right': [(1.801, 2.6485)]}, 'OA4_100_1': {'left': [(0.687, 1.3895), (1.772, 2.4645)], 'right': [(1.2465, 1.921)]}, 'OA4_100_2': {'left': [(0.8845, 1.5495), (1.9045, 2.5755)], 'right': [(1.4045, 2.061)]}, 'OA4_100_3': {'left': [(0.5975, 1.2585), (1.6275, 2.2835)], 'right': [(1.1135, 1.7725)]}, 'OA4_100_4': {'left': [(0.839, 1.52), (1.8865, 2.5815)], 'right': [(1.375, 2.043)]}, 'OA4_100_5': {'left': [(0.6185, 1.318)], 'right': [(0.0765, 0.778), (1.1535, 1.859)]}, 'OA4_120_1': {'left': [(0.4965, 1.0935), (1.4345, 1.94)], 'right': [(0.974, 1.553)]}, 'OA4_120_2': {'left': [(1.168, 1.769)], 'right': [(0.6935, 1.292), (1.646, 2.253)]}, 'OA4_120_3': {'left': [(0.959, 1.551)], 'right': [(0.5555, 1.0835), (1.431, 2.0425)]}, 'OA4_120_4': {'left': [(1.234, 1.845)], 'right': [(0.7445, 1.36), (1.726, 2.3505)]}, 'OA4_120_5': {'left': [(0.551, 1.1435)], 'right': [(1.0285, 1.643)]}}, 'OA5': {'OA5_80_1': {'left': [(0.556, 1.344), (1.7535, 2.5)], 'right': [(1.1705, 1.9275)]}, 'OA5_80_2': {'left': [(0.744, 1.4895), (1.913,  ...
# [{'subject': 'OA2_120_1', 'side': 'left', 'start_time': 1.114, 'end_time': 1.7065}, {'subject': 'OA2_120_2', 'side': 'left', 'start_time': 0.7325, 'end_time': 1.3095}, {'subject': 'OA2_120_3', 'side': 'left', 'start_time': 0.8145, 'end_time': 1.404}, {'subject': 'OA2_120_5', 'side': 'left', 'start_time': 0.745, 'end_time': 1.3435}, {'subject': 'OA5_80_1', 'side': 'right', 'start_time': 1.1705, 'end_time': 1.9275}, {'subject': 'OA5_80_2', 'side': 'right', 'start_time': 1.3135, 'end_time': 2.114}, {'subject': 'OA5_80_3', 'side': 'right', 'start_time': 1.3695, 'end_time': 2.107}, {'subject': 'OA5_80_4', 'side': 'right', 'start_time': 1.3665, 'end_time': 2.099}, {'subject': 'OA5_80_5', 'side': 'right', 'start_time': 1.19, 'end_time': 1.947}, {'subject': 'OA5_100_1', 'side': 'right', 'start_time': 0.695, 'end_time': 1.3235}, {'subject': 'OA5_100_1', 'side': 'right', 'start_time': 1.6875, 'end_time': 2.345}, {'subject': 'OA5_100_2', 'side': 'right', 'start_time': 0.4095, 'end_time': 1.051}, {'subject': 'OA5_100_2', 'side': 'right', 'start_time': 1.433, 'end_time': 2.0915}, {'subject': 'OA5_100_3', 'side': 'right', 'start_time': 0.6055, 'end_time': 1.1545}, {'subject': 'OA5_100_3', 'side': 'right', 'start_time': 1.5375, 'end_time': 2.2155}, {'subject': 'OA5_100_4', 'side': 'right', 'start_time': 1.131, 'end_time': 1.7875}, {'subject': 'OA5_100_5', 'side': 'right', 'start_time': 1.1805, 'end_time': 1.844}, {'subject': 'OA5_120_1', 'side': 'left', 'start_time': 0.959, 'end_time': 1.557}, {'subject': 'OA5_120_1', 'side': 'right', 'start_time': 0.487, 'end_time': 1.0765}, {'subject': 'OA5_120_1', 'side': 'right', 'start_time': 1.4395, 'end_time': 2.041}, {'subject': 'OA5_120_2', 'side': 'left', 'start_time': 0.9525, 'end_time': 1.543}, {'subject': 'OA5_120_2', 'side': 'right', 'start_time': 0.472, 'end_time': 1.0695}, {'subject': 'OA5_120_2', 'side': 'right', 'start_time': 1.4225, 'end_time': 2.0305}, {'subject': 'OA5_120_3', 'side': 'right', 'start_time': 0.4315, 'end_time': 1.031}, {'subject': 'OA5_120_3', 'side': 'right', 'start_time': 1.3895, 'end_time': 1.941}, {'subject': 'OA5_120_4', 'side': 'left', 'start_time': 0.942, 'end_time': 1.5315}, {'subject': 'OA5_120_4', 'side': 'right', 'start_time': 0.4685, 'end_time': 1.0635}, {'subject': 'OA5_120_5', 'side': 'left', 'start_time': 1.1125, 'end_time': 1.694}, {'subject': 'OA5_120_5', 'side': 'right', 'start_time': 0.65, 'end_time': 1.227}, {'subject': 'OA11_80_2', 'side': 'right', 'start_time': 1.1125, 'end_time': 1.785}, {'subject': 'OA11_80_3', 'side': 'right', 'start_time': 1.0305, 'end_time': 1.728}, {'subject': 'OA11_80_4', 'side': 'right', 'start_time': 1.0895, 'end_time': 1.81}, {'subject': 'OA11_80_5', 'side': 'right', 'start_time': 1.0065, 'end_time': 1.7125}, {'subject': 'OA11_100_3', 'side': 'right', 'start_time': 0.6215, 'end_time': 1.174}, {'subject': 'OA11_120_1', 'side': 'right', 'start_time': 0.978, 'end_time': 1.5555}, {'subject': 'OA11_120_2', 'side': 'right', 'start_time': 0.737, 'end_time': 1.314}, {'subject': 'OA11_120_3', 'side': 'right', 'start_time': 0.622, 'end_time': 1.204}, {'subject': 'OA11_120_4', 'side': 'right', 'start_time': 0.836, 'end_time': 1.396}, {'subject': 'OA11_120_5', 'side': 'right', 'start_time': 0.7705, 'end_time': 1.3325}, {'subject': 'OA12_100_1', 'side': 'right', 'start_time': 1.318, 'end_time': 1.9895}, {'subject': 'OA17_80_1', 'side': 'left', 'start_time': 0.976, 'end_time': 1.7185}, {'subject': 'OA17_80_1', 'side': 'left', 'start_time': 2.181, 'end_time': 3.034}, {'subject': 'OA19_80_2', 'side': 'right', 'start_time': 1.5215, 'end_time': 2.3245}, {'subject': 'OA23_80_1', 'side': 'left', 'start_time': 0.579, 'end_time': 1.3275}, {'subject': 'OA23_80_1', 'side': 'left', 'start_time': 1.7535, 'end_time': 2.494}, {'subject': 'OA23_80_2', 'side': 'left', 'start_time': 0.5955, 'end_time': 1.3995}, {'subject': 'OA23_80_2', 'side': 'left', 'start_time': 1.838, 'end_time': 2.6275}, {'subject': 'OA23_80_3', 'side': 'left', 'start_time': 0.626, ' ...

# %%
left = 0
right = 0
for subjects, trials in all_segs.items():
    for trial_data in trials.values():
        left += len(trial_data['left'])
        right += len(trial_data['right'])
print(f'{left} left foot segments')
print(f'{right} right foot segments')
print(f'{left + right} segments total')
# Out:
# 826 left foot segments
# 862 right foot segments
# 1688 segments total

# %% [markdown]
# # Extract Muscle Force Segments
#
# Call `data_to_segs` to iterate over every subject and trial in `all_segs`, load the corresponding GRF pickle and Static Optimization (SO) `.sto` results file, and slice each signal into stance-phase segments using the heel-strike/toe-off time windows found in 'all_segs'. Both right and left limbs are handled, with the medial-lateral GRF sign flipped for left-side contacts. An optional Achilles force channel is computed as the sum of gastrocnemius lateralis, gastrocnemius medialis, and soleus. Segments flagged in `problem_seg_keys` are skipped. The output `all_muscle_segs` is a subject-keyed dict of signal-keyed segment lists.

# %%
muscles = [
    "addbrev_r", "addlong_r", "addmagDist_r", "addmagIsch_r", "addmagMid_r", "addmagProx_r",
    "bflh_r", "bfsh_r", "edl_r", "ehl_r", "fdl_r", "fhl_r", "gaslat_r", "gasmed_r",
    "glmax1_r", "glmax2_r", "glmax3_r", "glmed1_r", "glmed2_r", "glmed3_r",
    "glmin1_r", "glmin2_r", "glmin3_r", "grac_r", "iliacus_r", "perbrev_r", "perlong_r",
    "psoas_r", "recfem_r", "semimem_r", "semiten_r", "soleus_r",
    "tibant_r", "tibpost_r", "vasint_r", "vaslat_r", "vasmed_r",

    "addbrev_l", "addlong_l", "addmagDist_l", "addmagIsch_l", "addmagMid_l", "addmagProx_l",
    "bflh_l", "bfsh_l", "edl_l", "ehl_l", "fdl_l", "fhl_l", "gaslat_l", "gasmed_l",
    "glmax1_l", "glmax2_l", "glmax3_l", "glmed1_l", "glmed2_l", "glmed3_l",
    "glmin1_l", "glmin2_l", "glmin3_l", "grac_l", "iliacus_l", "perbrev_l", "perlong_l",
    "psoas_l", "recfem_l", "semimem_l", "semiten_l", "soleus_l",
    "tibant_l", "tibpost_l", "vasint_l", "vaslat_l", "vasmed_l"
]
problem_trials = []

so_dir = '/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO'

# JRF files live in the same SO trial subfolders as results_forces.sto
jrf_dir      = so_dir
jrf_filename = 'results_JointReaction_JointRxn_ReactionLoads.sto'

jrf_col_map = {
    # output key             right-side column                                    left-side column
    'knee_fx':  {'r': 'walker_knee_r_on_tibia_r_in_tibia_r_fx',         'l': 'walker_knee_l_on_tibia_l_in_tibia_l_fx'},
    'knee_fy':  {'r': 'walker_knee_r_on_tibia_r_in_tibia_r_fy',         'l': 'walker_knee_l_on_tibia_l_in_tibia_l_fy'},
    'knee_fz':  {'r': 'walker_knee_r_on_tibia_r_in_tibia_r_fz',         'l': 'walker_knee_l_on_tibia_l_in_tibia_l_fz'},
    'ankle_fx': {'r': 'ankle_r_on_talus_r_in_talus_r_fx',               'l': 'ankle_l_on_talus_l_in_talus_l_fx'},
    'ankle_fy': {'r': 'ankle_r_on_talus_r_in_talus_r_fy',               'l': 'ankle_l_on_talus_l_in_talus_l_fy'},
    'ankle_fz': {'r': 'ankle_r_on_talus_r_in_talus_r_fz',               'l': 'ankle_l_on_talus_l_in_talus_l_fz'},
}

all_muscle_segs, problematic_force_segs = data_to_segs(
    muscles=muscles,
    seg_times=all_segs,
    problem_trials=problem_trials,
    grf_pickle_dir='/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Transformed/grf_pickles',
    muscle_force_dir=so_dir,
    problematic_seg_keys=problem_seg_keys,
    jrf_dir=jrf_dir,
    jrf_filename=jrf_filename,
    jrf_col_map=jrf_col_map,
)

n_segs = sum(
    len(subj_data["grf_y"])
    for subj_data in all_muscle_segs.values()
)
print(n_segs, 'gait cycles')
# Out:
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_1/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_2/results_forces.sto (nr=286 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=286 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_3/results_forces.sto (nr=286 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=286 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_4/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_5/results_forces.sto (nr=273 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=273 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_1/results_forces.sto (nr=225 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=225 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_2/results_forces.sto (nr=245 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=245 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_3/results_forces.sto (nr=229 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=229 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_4/results_forces.sto (nr=246 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=246 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_5/results_forces.sto (nr=230 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=230 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_1/results_forces.sto (nr=196 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=196 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_2/results_forces.sto (nr=198 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=198 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_3/results_forces.sto (nr=182 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=182 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_4/results_forces.sto (nr=204 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=204 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_5/results_forces.sto (nr=193 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA1_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=193 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_1/results_forces.sto (nr=284 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=284 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_2/results_forces.sto (nr=234 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=234 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_3/results_forces.sto (nr=272 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=272 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_4/results_forces.sto (nr=249 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=249 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_5/results_forces.sto (nr=263 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=263 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_1/results_forces.sto (nr=221 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=221 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_2/results_forces.sto (nr=204 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=204 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_3/results_forces.sto (nr=218 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=218 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_4/results_forces.sto (nr=203 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=203 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_5/results_forces.sto (nr=222 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=222 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_1/results_forces.sto (nr=178 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=178 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_2/results_forces.sto (nr=175 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=175 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_3/results_forces.sto (nr=192 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=192 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_4/results_forces.sto (nr=190 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=190 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_5/results_forces.sto (nr=190 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA2_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=190 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_1/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_2/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_3/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_4/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_5/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_1/results_forces.sto (nr=274 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=274 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_2/results_forces.sto (nr=285 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=285 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_3/results_forces.sto (nr=254 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=254 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_4/results_forces.sto (nr=266 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=266 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_5/results_forces.sto (nr=235 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=235 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_1/results_forces.sto (nr=228 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=228 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_2/results_forces.sto (nr=257 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=257 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_3/results_forces.sto (nr=234 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=234 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_4/results_forces.sto (nr=255 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=255 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_5/results_forces.sto (nr=230 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA4_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=230 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_1/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_2/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_3/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_4/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_5/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_1/results_forces.sto (nr=260 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=260 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_2/results_forces.sto (nr=238 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=238 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_3/results_forces.sto (nr=260 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=260 nc=37)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_4/results_forces.sto (nr=252 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=252 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_5/results_forces.sto (nr=263 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=263 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_1/results_forces.sto (nr=227 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=227 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_2/results_forces.sto (nr=223 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=223 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_3/results_forces.sto (nr=220 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=220 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_4/results_forces.sto (nr=228 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=228 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_5/results_forces.sto (nr=239 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA5_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=239 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_1/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_2/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_3/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_4/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_5/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_1/results_forces.sto (nr=268 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=268 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_2/results_forces.sto (nr=267 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=267 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_3/results_forces.sto (nr=259 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=259 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_4/results_forces.sto (nr=240 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=240 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_5/results_forces.sto (nr=251 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=251 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_1/results_forces.sto (nr=211 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=211 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_2/results_forces.sto (nr=220 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=220 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_3/results_forces.sto (nr=205 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=205 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_4/results_forces.sto (nr=216 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=216 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_5/results_forces.sto (nr=210 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA7_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=210 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_1/results_forces.sto (nr=254 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=254 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_2/results_forces.sto (nr=263 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=263 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_3/results_forces.sto (nr=253 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=253 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_4/results_forces.sto (nr=279 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=279 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_5/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_1/results_forces.sto (nr=259 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=259 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_2/results_forces.sto (nr=211 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=211 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_3/results_forces.sto (nr=230 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=230 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_4/results_forces.sto (nr=236 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=236 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_5/results_forces.sto (nr=224 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=224 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_1/results_forces.sto (nr=195 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=195 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_2/results_forces.sto (nr=200 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=200 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_3/results_forces.sto (nr=181 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=181 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_4/results_forces.sto (nr=193 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=193 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_5/results_forces.sto (nr=225 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA8_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=225 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_1/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_2/results_forces.sto (nr=256 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=256 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_3/results_forces.sto (nr=270 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=270 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_4/results_forces.sto (nr=281 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=281 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_5/results_forces.sto (nr=280 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=280 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_1/results_forces.sto (nr=244 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=244 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_2/results_forces.sto (nr=237 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=237 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_3/results_forces.sto (nr=254 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=254 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_4/results_forces.sto (nr=241 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=241 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_5/results_forces.sto (nr=229 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=229 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_1/results_forces.sto (nr=174 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=174 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_2/results_forces.sto (nr=184 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=184 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_3/results_forces.sto (nr=179 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=179 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_4/results_forces.sto (nr=196 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=196 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_5/results_forces.sto (nr=186 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA9_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=186 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_1/results_forces.sto (nr=273 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=273 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_2/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_3/results_forces.sto (nr=274 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=274 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_4/results_forces.sto (nr=278 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=278 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_5/results_forces.sto (nr=289 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=289 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_1/results_forces.sto (nr=223 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=223 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_2/results_forces.sto (nr=218 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=218 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_3/results_forces.sto (nr=230 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=230 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_4/results_forces.sto (nr=243 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=243 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_5/results_forces.sto (nr=242 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=242 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_1/results_forces.sto (nr=174 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=174 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_2/results_forces.sto (nr=192 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=192 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_3/results_forces.sto (nr=205 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=205 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_4/results_forces.sto (nr=204 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=204 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_5/results_forces.sto (nr=204 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA10_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=204 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_1/results_forces.sto (nr=222 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=222 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_2/results_forces.sto (nr=258 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=258 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_3/results_forces.sto (nr=247 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=247 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_4/results_forces.sto (nr=258 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=258 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_5/results_forces.sto (nr=241 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=241 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_1/results_forces.sto (nr=184 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=184 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_2/results_forces.sto (nr=198 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=198 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_3/results_forces.sto (nr=184 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=184 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_4/results_forces.sto (nr=200 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=200 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_5/results_forces.sto (nr=229 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=229 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_1/results_forces.sto (nr=160 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=160 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_2/results_forces.sto (nr=140 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=140 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_3/results_forces.sto (nr=128 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=128 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_4/results_forces.sto (nr=151 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=151 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_5/results_forces.sto (nr=147 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA11_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=147 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_1/results_forces.sto (nr=279 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=279 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_2/results_forces.sto (nr=267 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=267 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_3/results_forces.sto (nr=260 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=260 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_4/results_forces.sto (nr=233 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=233 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_5/results_forces.sto (nr=230 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=230 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_100_1/results_forces.sto (nr=204 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=204 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_100_2/results_forces.sto (nr=199 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/OA12_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=199 nc=127)
# ...
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y19_120_4/results_forces.sto (nr=206 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y19_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=206 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y19_120_5/results_forces.sto (nr=213 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y19_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=213 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_1/results_forces.sto (nr=166 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=166 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_2/results_forces.sto (nr=175 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=175 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_3/results_forces.sto (nr=175 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=175 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_4/results_forces.sto (nr=175 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=175 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_5/results_forces.sto (nr=175 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=175 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_1/results_forces.sto (nr=164 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=164 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_2/results_forces.sto (nr=148 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=148 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_3/results_forces.sto (nr=153 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=153 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_4/results_forces.sto (nr=158 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=158 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_5/results_forces.sto (nr=146 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=146 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_1/results_forces.sto (nr=145 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=145 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_2/results_forces.sto (nr=143 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=143 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_3/results_forces.sto (nr=139 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=139 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_4/results_forces.sto (nr=140 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=140 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_5/results_forces.sto (nr=141 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y20_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=141 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_1/results_forces.sto (nr=272 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=272 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_2/results_forces.sto (nr=276 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=276 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_3/results_forces.sto (nr=281 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=281 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_4/results_forces.sto (nr=285 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=285 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_5/results_forces.sto (nr=290 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=290 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_1/results_forces.sto (nr=246 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=246 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_2/results_forces.sto (nr=213 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=213 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_3/results_forces.sto (nr=240 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=240 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_4/results_forces.sto (nr=237 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=237 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_5/results_forces.sto (nr=228 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=228 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_1/results_forces.sto (nr=189 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=189 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_2/results_forces.sto (nr=186 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=186 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_3/results_forces.sto (nr=202 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=202 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_4/results_forces.sto (nr=196 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=196 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_5/results_forces.sto (nr=193 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y21_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=193 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_1/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_2/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_3/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_4/results_forces.sto (nr=291 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=291 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_5/results_forces.sto (nr=284 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_80_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=284 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_1/results_forces.sto (nr=256 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=256 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_2/results_forces.sto (nr=227 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=227 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_3/results_forces.sto (nr=238 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=238 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_4/results_forces.sto (nr=247 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=247 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_5/results_forces.sto (nr=242 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_100_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=242 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_1/results_forces.sto (nr=195 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_1/results_JointReaction_JointRxn_ReactionLoads.sto (nr=195 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_2/results_forces.sto (nr=209 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_2/results_JointReaction_JointRxn_ReactionLoads.sto (nr=209 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_3/results_forces.sto (nr=194 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_3/results_JointReaction_JointRxn_ReactionLoads.sto (nr=194 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_4/results_forces.sto (nr=198 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_4/results_JointReaction_JointRxn_ReactionLoads.sto (nr=198 nc=127)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_5/results_forces.sto (nr=205 nc=118)
# [info] Storage: read data file = /Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/Results/SO/Y22_120_5/results_JointReaction_JointRxn_ReactionLoads.sto (nr=205 nc=127)
# 1584 gait cycles

# %% [markdown]
# # Resample Segments to a Common Time Grid
#
# Interpolate every segment for every signal and subject onto a fixed 100-point time grid using `interp_segments`. The result `resampled_segs` mirrors the structure of `all_muscle_segs` but with uniform-length arrays, enabling straightforward stacking and averaging across trials. A shared `'time_resampled'` key is appended to the dict for use as the x-axis in downstream plots.

# %%
n_interp_points = 100
resampled_segs = {}

for subj, subj_data in all_muscle_segs.items():
    resampled_segs[subj] = {}
    for key, seg_list in subj_data.items():
        if len(seg_list) == 0:
            resampled_segs[subj][key] = []
            continue 
        resampled, time_resampled = interp_segments(seg_list, n_interp_points)
        resampled_segs[subj][key] = resampled
resampled_segs['time_resampled'] = time_resampled

# %% [markdown]
# # Normalize Forces by Body Mass
#
# Divide all muscle forces by each subject's body mass (kg) to produce body-mass-normalized forces (N/kg), making comparisons across subjects and between the OA and young-adult (YA) cohorts more meaningful. Subject masses are listed in the same order as the subjects in `resampled_segs`. The normalized output is stored in `normalized_muscle_segs`.

# %%
base_muscles = sorted({m[:-2] for m in muscles if m.endswith(("_r", "_l"))})
base_muscles.append('achilles')

base_jrfs = list(jrf_col_map.keys())

OA_subj_masses = [63.5026, 61.68824, 68.0385, 68.0385, 59.87388, 76.65671, 57.15234, 71.66722,
               84.36774, 67.13132, 52.61644, 70.76004, 75.29594, 69.39927, 83.00697, 47.62695,
              61.68824, 84.82133, 74.38876, 83.91415]
Y_subj_masses = [63, 85, 54, 60, 54, 83, 53, 62, 72, 65, 84, 83, 64, 59, 77.56389, 55, 73, 90, 75, 65, 68]
subj_masses = OA_subj_masses + Y_subj_masses

normalizer_keys = base_muscles + base_jrfs + ['grf_x', 'grf_y', 'grf_z']
normalized_segs = normalize_by_mass_in_order(resampled_segs, subj_masses, normalizer_keys)

# %% [markdown]
# # Filter out trials that are consistently/extremely out of distribution

# %%
# â”€â”€ Run Mean +/- 2 std and RMS filter â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
# mode  : 'any' drops a segment if ANY muscle is flagged (strict)
#          use 'all' for a more lenient filter
consistency_mode = 'any'
rms_threshold = 0.75
mean_threshold = 0.7

filter_keys = base_muscles + base_jrfs + ['grf_x', 'grf_y', 'grf_z', 'cop_x']

normalized_segs_filtered, dropped, bands = filter_segments(
    seg_dict=normalized_segs,
    muscle_keys=filter_keys,
    consistency_mode=consistency_mode,
    rms_threshold=rms_threshold,
    mean_threshold=mean_threshold,
)

# â”€â”€ Summary â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
n_before = sum(
    len(data.get('achilles', []))
    for data in normalized_segs.values()
    if isinstance(data, dict)
)
n_after = sum(
    len(data.get('achilles', []))
    for data in normalized_segs_filtered.values()
    if isinstance(data, dict)
)
print(f'Segments before MAD filter : {n_before}')
print(f'Segments after  MAD filter : {n_after}')
print(f'Dropped                    : {len(dropped)} ({100*len(dropped)/n_before:.1f}%)')

# Which muscles triggered the most drops?
from collections import Counter
c = Counter()
for _, _, bad_muscles in dropped:
    c.update(bad_muscles)
print('\nTop muscles triggering drops:')
for muscle, count in c.most_common(10):
    print(f'  {muscle:<20} {count}')
# Out:
# /opt/anaconda3/envs/opensim_scripting/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /Users/briankeller/Desktop/GRFMuscleModel/OA_Scripts/OA_utils/data_utils.py:450: RuntimeWarning: overflow encountered in power
#   rms_excess = np.sqrt(np.mean(excess**4))   # catches peaky outliers
# Segments before MAD filter : 1584
# Segments after  MAD filter : 1002
# Dropped                    : 582 (36.7%)
#
# Top muscles triggering drops:
#   ankle_fy             182
#   achilles             155
#   knee_fy              134
#   soleus               115
#   recfem               93
#   gasmed               93
#   vaslat               87
#   grf_y                78
#   psoas                74
#   semimem              72

# %% [markdown]
# # Plot Segmented GRF Data

# %%
grf_y_resampled = get_all_segments(normalized_segs_filtered, 'grf_y')
time_resampled = normalized_segs_filtered['time_resampled']
grf_x_resampled = get_all_segments(normalized_segs_filtered, 'grf_x')
time_resampled = normalized_segs_filtered['time_resampled']
grf_z_resampled = get_all_segments(normalized_segs_filtered, 'grf_z')
time_resampled = normalized_segs_filtered['time_resampled']
# Stack into arrays
grf_y = np.array(grf_y_resampled)
grf_x = np.array(grf_x_resampled)
grf_z = np.array(grf_z_resampled)
time = time_resampled[0] * 100  # percent stance

# Set up 3-column subplot
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharex=True)

# Define GRF components
components = [
    ("Vertical", grf_y),
    ("Anterior-Posterior", grf_x),
    ("Medial-Lateral", grf_z)
]

colors = {
    'fill': '#5190E4',
    'line': '#1A5EB6'
}
num_grf_segments = len(grf_y_resampled)
for ax, (label, grf_array) in zip(axes, components):
    mean_grf = np.mean(grf_array, axis=0)
    
    for i in range(num_grf_segments):
        ax.plot(time, grf_array[i], linewidth=2, color="#A2C7E7", alpha=0.4)

    # Mean line
    ax.plot(time, mean_grf, color=colors['line'], linewidth=3, label='Mean GRF')
    
    ax.set_title(f"{label}", fontsize=18)
    ax.set_xlabel("Percent Normalized Stance (%)", fontsize=16)
    ax.tick_params(axis='both', labelsize=16)
    ax.set_axis_off()
    # ax.grid(True, alpha=0.3)

axes[0].set_ylabel("Ground Reaction Force (N)", fontsize=16)
# axes[0].legend(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot COP Data

# %%
cop_x_resampled = get_all_segments(normalized_segs_filtered, 'cop_x')
time_resampled = normalized_segs_filtered['time_resampled']
figure = plt.figure(figsize=(10, 10))

num_cop_segments = len(cop_x_resampled)

for i in range(num_cop_segments):
    plt.plot(time_resampled[0] * 100, cop_x_resampled[i], linewidth=2)

plt.ylabel("X Component of Center of Pressure", fontsize=18)
plt.xlabel("Percent Normalized Stance", fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# plt.xlim([0, 1])
# plt.ylim([0, 1200])
# Out:
# (array([-0.025,  0.   ,  0.025,  0.05 ,  0.075,  0.1  ,  0.125,  0.15 ,
#          0.175,  0.2  ,  0.225]),
#  [Text(0, -0.025, '−0.025'),
#   Text(0, 0.0, '0.000'),
#   Text(0, 0.025, '0.025'),
#   Text(0, 0.05000000000000001, '0.050'),
#   Text(0, 0.07500000000000001, '0.075'),
#   Text(0, 0.1, '0.100'),
#   Text(0, 0.12500000000000003, '0.125'),
#   Text(0, 0.15000000000000002, '0.150'),
#   Text(0, 0.17500000000000002, '0.175'),
#   Text(0, 0.2, '0.200'),
#   Text(0, 0.225, '0.225')])

# %% [markdown]
# # Plot Muscle Forces

# %%
achilles_resampled = get_all_segments(normalized_segs_filtered, 'achilles')
mean_achilles  = np.mean(achilles_resampled, axis=0)
std_achilles = np.std(achilles_resampled, axis=0)


lo = mean_achilles - 2 * std_achilles
hi = mean_achilles + 2 * std_achilles
for seg in achilles_resampled:
    outside = (seg < lo) | (seg > hi)
    
plt.figure(figsize=(10, 6))
t = np.linspace(0, 100, achilles_resampled.shape[1])
plt.fill_between(t, lo, hi, alpha = 0.1)
plt.plot(t, mean_achilles)
plt.title('MAD Band for Achilles Segment Exlcusion')

plot_achilles_segments(achilles_resampled, time_resampled)

# %% [markdown]
# # Plot Filtered Muscle Forces

# %%
resampled_filtered_muscles = flatten_to_muscle_dict(normalized_segs_filtered, base_muscles)

plot_muscle_grid(
    resampled_filtered_muscles,
    time_resampled,
    base_muscles,
    plot_mean=True
)

# %% [markdown]
# # Plot Filtered Joint Contact Forces

# %%
resampled_filtered_jrfs = flatten_to_muscle_dict(normalized_segs_filtered, base_jrfs)

plot_muscle_grid(
    resampled_filtered_jrfs,
    time_resampled,
    base_jrfs,
    plot_mean=True
)

# %% [markdown]
# # Plot Unfiltered Muscle Forces

# %%
resampled_muscles = flatten_to_muscle_dict(normalized_segs, base_muscles)

plot_muscle_grid(
    resampled_muscles,
    time_resampled,
    base_muscles,
    plot_mean=True
)

# %%
# --- Load Tony's (Ulrich) subject-stratified dataset ---
tony_dir = '/Users/briankeller/Desktop/GRFMuscleModel/data/'
with open(tony_dir + 'resampled_Ulrich_segments.pkl', 'rb') as f:
    tony_segs = pickle.load(f)
subject_keys = [k for k, v in tony_segs.items() if isinstance(v, dict)]
print(subject_keys)
tony_muscle_labels = ['tibpost', 'tibant', 'edl', 'ehl', 'fdl', 'fhl', 'perbrev', 'perlong', 'achilles']
tony_masses = np.array([86.04, 50.71, 92.25, 65.31, 69.29, 83.48, 61.98, 68.73, 66.3, 64.22])
print(len(tony_masses))

# Normalize by body mass (N -> N/kg), same logic as normalize_by_mass_in_order
tony_segs_normalized = normalize_by_mass_in_order(tony_segs, tony_masses, tony_muscle_labels)

# --- Pick the muscle to plot (single-muscle sanity check) ---
muscle_idx = 8  # Achilles (0-based index)
muscle_name = tony_muscle_labels[muscle_idx]

oa_muscles_single = flatten_to_muscle_dict(normalized_segs_filtered, tony_muscle_labels)
ya_muscles_single = flatten_to_muscle_dict(tony_segs_normalized, tony_muscle_labels)

oa_segs = oa_muscles_single[muscle_name]  # (N_oa, 100)
ya_segs = ya_muscles_single[muscle_name]  # (N_ya, 100)
t_oa   = resampled_segs['time_resampled'][0] * 100
t_tony = tony_segs['time_resampled'][0] * 100

# --- Create figure ---
plt.figure(figsize=(8, 5))

for seg in oa_segs:
    plt.plot(t_oa,   seg, color='#A2C7E7', linewidth=1.5, alpha=0.4)
for seg in ya_segs:
    plt.plot(t_tony, seg, color='#E7A9A2', linewidth=1.5, alpha=0.08)

plt.plot(t_oa,   oa_segs.mean(axis=0), color='#005A9C', linewidth=3, label='OA mean')
plt.plot(t_tony, ya_segs.mean(axis=0), color='#9C2B00', linewidth=3, label='YA mean')

plt.title(f'{muscle_name} â€” OA vs. YA (mass-normalized, Static Optimization)', fontsize=14)
plt.xlabel('Percent Stance (%)', fontsize=12)
plt.ylabel('Force (N/kg)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ['Subject1', 'Subject2', 'Subject3', 'Subject4', 'Subject5', 'Subject6', 'Subject7', 'Subject8', 'Subject9', 'Subject10']
# 10

# %%
tony_dir = '/Users/briankeller/Desktop/GRFMuscleModel/data/'
with open(tony_dir + 'resampled_Ulrich_segments.pkl', 'rb') as f:
    tony_segs = pickle.load(f)

tony_muscle_labels = ['tibpost', 'tibant', 'edl', 'ehl', 'fdl', 'fhl', 'perbrev', 'perlong', 'achilles']
tony_masses = np.array([86.04, 50.71, 92.25, 65.31, 69.29, 83.48, 61.98, 68.73, 66.3, 64.22])

tony_segs_normalized = normalize_by_mass_in_order(tony_segs, tony_masses, tony_muscle_labels)

oa_muscles = flatten_to_muscle_dict(normalized_segs_filtered, tony_muscle_labels)
ya_muscles = flatten_to_muscle_dict(tony_segs_normalized, tony_muscle_labels)
t_oa   = resampled_segs['time_resampled'][0] * 100
t_tony = tony_segs['time_resampled'][0] * 100

fig, axes = plt.subplots(3, 3, figsize=(15, 10))
axes = axes.flatten()

for i, ax in enumerate(axes):
    muscle = tony_muscle_labels[i]
    oa_s = oa_muscles[muscle]  # (N_oa, 100)
    ya_s = ya_muscles[muscle]  # (N_ya, 100)

    for seg in oa_s:
        ax.plot(t_oa,   seg, linewidth=1.5, color='#A2C7E7', alpha=0.3)
    for seg in ya_s:
        ax.plot(t_tony, seg, linewidth=1.5, color='#E7A9A2', alpha=0.05)

    ax.plot(t_oa,   oa_s.mean(axis=0), color='#005A9C', linewidth=2.5, label='OA mean')
    ax.plot(t_tony, ya_s.mean(axis=0), color='#9C2B00', linewidth=2.5, label='YA mean')

    ax.set_title(muscle, fontsize=18)
    ax.tick_params(axis='x', labelsize=16)
    ax.tick_params(axis='y', labelsize=16)
    ax.legend(fontsize=10)
    if i >= 6:
        ax.set_xlabel('Percent Normalized Stance', fontsize=12)
    if i % 3 == 0:
        ax.set_ylabel('Muscle Force (N/kg)', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ry/__2whx491kl275m5nl07mrnr0000gn/T/ipykernel_66061/987894539.py:40: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /opt/anaconda3/envs/opensim_scripting/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
with open('/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/OA_muscle_forces_stats_100.txt', "w") as file:
    for i, muscle in enumerate(base_muscles):
        all_forces = np.concatenate(muscle_forces[i])
        # max_val = np.max(all_forces)
        # min_val = np.min(all_forces)
        max_vals = [np.max(seg) for seg in muscle_forces[i]]
        max_mean = np.mean(max_vals)
        max_std = np.std(max_vals)
        
        min_vals = [np.min(seg) for seg in muscle_forces[i]]
        min_mean = np.mean(min_vals)
        min_std = np.std(min_vals)
        
        mean_val = np.mean(all_forces)
        std_val = np.std(all_forces)
        
        print(f"{muscle}:\n Mean Max = {max_mean:.2f}\n Std Max = {max_std:.2f}\n Mean Min = {min_mean:.2f}\n Std Min = {min_std:.2f}\n Mean = {mean_val:.2f}\n Std = {std_val:.2f}\n")
        file.write(f"{muscle}:\n Mean Max = {max_mean:.2f}\n Std Max = {max_std:.2f}\n Mean Min = {min_mean:.2f}\n Std Min = {min_std:.2f}\n Mean = {mean_val:.2f}\n Std = {std_val:.2f}\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 with open('/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/OA_muscle_forces_stats_100.txt', "w") as file:
# ----> 2     for i, muscle in enumerate(muscle_titles):
#       3         all_forces = np.concatenate(muscle_forces[i])
#       4         # max_val = np.max(all_forces)
#       5         # min_val = np.min(all_forces)
#
# NameError: name 'muscle_titles' is not defined

# %%
with open('/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/OA_muscle_forces_stats_25.txt', "w") as file:
    for i, muscle in enumerate(muscle_titles):
        all_forces = np.concatenate(muscle_forces[i])
        # max_val = np.max(all_forces)
        # min_val = np.min(all_forces)
        max_vals = [np.max(seg) for seg in muscle_forces[i]]
        max_mean = np.mean(max_vals) / 4
        max_std = np.std(max_vals) / 4
        
        min_vals = [np.min(seg) for seg in muscle_forces[i]]
        min_mean = np.mean(min_vals) / 4
        min_std = np.std(min_vals) / 4
        
        mean_val = np.mean(all_forces) / 4
        std_val = np.std(all_forces) / 4
        
        print(f"{muscle}:\n Mean Max = {max_mean:.2f}\n Std Max = {max_std:.2f}\n Mean Min = {min_mean:.2f}\n Std Min = {min_std:.2f}\n Mean = {mean_val:.2f}\n Std = {std_val:.2f}\n")
        file.write(f"{muscle}:\n Mean Max = {max_mean:.2f}\n Std Max = {max_std:.2f}\n Mean Min = {min_mean:.2f}\n Std Min = {min_std:.2f}\n Mean = {mean_val:.2f}\n Std = {std_val:.2f}\n\n")
# Out:
# Tibialis Posterior:
#  Mean Max = 88.07
#  Std Max = 38.47
#  Mean Min = 18.91
#  Std Min = 4.68
#  Mean = 46.56
#  Std = 30.57
#
# Tibialis Anterior:
#  Mean Max = 82.92
#  Std Max = 30.67
#  Mean Min = 2.58
#  Std Min = 0.54
#  Mean = 20.09
#  Std = 26.60
#
# Extensor Digitorum Longus:
#  Mean Max = 21.49
#  Std Max = 10.95
#  Mean Min = 1.36
#  Std Min = 0.04
#  Mean = 4.20
#  Std = 6.66
#
# Extensor Hallucis Longus:
#  Mean Max = 4.42
#  Std Max = 1.96
#  Mean Min = 0.66
#  Std Min = 0.01
#  Mean = 1.22
#  Std = 1.24
#
# Flexor Digitorum Longus:
#  Mean Max = 4.94
#  Std Max = 2.20
#  Mean Min = 1.17
#  Std Min = 0.26
#  Mean = 2.62
#  Std = 1.69
#
# Flexor Hallucis Longus:
#  Mean Max = 15.26
#  Std Max = 8.52
#  Mean Min = 2.15
#  Std Min = 0.06
#  Mean = 6.84
#  Std = 6.61
#
# Peroneus Brevis:
#  Mean Max = 13.88
#  Std Max = 5.61
#  Mean Min = 1.77
#  Std Min = 0.74
#  Mean = 6.18
#  Std = 4.89
#
# Peroneus Longus:
#  Mean Max = 47.79
#  Std Max = 23.99
#  Mean Min = 7.13
#  Std Min = 2.75
#  Mean = 21.43
#  Std = 17.13
#
# Achilles:
#  Mean Max = 575.74
#  Std Max = 112.53
#  Mean Min = 23.65
#  Std Min = 4.27
#  Mean = 227.78
#  Std = 190.16

# %% [markdown]
# Export dictionary of resampled grfs and muscle forces keyed to their respective subjects

# %%
export_path = '/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/resampled_normalized_compiled_segments'
with open(export_path, 'wb') as f:
    pickle.dump(normalized_segs_filtered, f)

# %% [markdown]
# # Split into OA and YA Cohorts
#
# Split `normalized_segs_filtered` into separate dicts by cohort prefix (`"OA"` vs `"Y"`), preserving the shared `'time_resampled'` key in both. These can then be exported and mixed with external YA datasets for cross-dataset model training experiments.

# %%
OA_segs = {k: v for k, v in normalized_segs_filtered.items() if isinstance(k, str) and k.startswith('OA')}
YA_segs = {k: v for k, v in normalized_segs_filtered.items() if isinstance(k, str) and k.startswith('Y')}

# Carry over the shared time axis
OA_segs['time_resampled'] = normalized_segs_filtered['time_resampled']
YA_segs['time_resampled'] = normalized_segs_filtered['time_resampled']

print(f"OA subjects : {len(OA_segs) - 1}")   # -1 for time_resampled key
print(f"YA subjects : {len(YA_segs) - 1}")

# Segment counts
oa_n = sum(len(v.get('grf_y', [])) for v in OA_segs.values() if isinstance(v, dict))
ya_n = sum(len(v.get('grf_y', [])) for v in YA_segs.values() if isinstance(v, dict))
print(f"OA segments : {oa_n}")
print(f"YA segments : {ya_n}")
# Out:
# OA subjects : 20
# YA subjects : 21
# OA segments : 457
# YA segments : 545

# %% [markdown]
# ## Per-Subject Contents Summary
#
# Print the keys available and segment count for each subject in both cohorts.

# %%
def print_cohort_summary(segs_dict, cohort_name):
    subj_keys = [k for k in segs_dict if isinstance(k, str) and k != 'time_resampled']
    print(f"{'='*60}")
    print(f"  {cohort_name}  ({len(subj_keys)} subjects)")
    print(f"{'='*60}")
    for subj in sorted(subj_keys):
        data = segs_dict[subj]
        n_segs = len(data.get('grf_y', []))
        signal_keys = sorted(data.keys())
        print(f"\n  {subj}  â€”  {n_segs} segments")
        print(f"    signals ({len(signal_keys)}): {', '.join(signal_keys)}")
    print()

print_cohort_summary(OA_segs, "OA")
print_cohort_summary(YA_segs, "YA")
# Out:
# ============================================================
#   OA  (20 subjects)
# ============================================================
#
#   OA1  â€”  40 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA10  â€”  30 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA11  â€”  6 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA12  â€”  18 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA13  â€”  31 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA14  â€”  32 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA17  â€”  26 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA18  â€”  35 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA19  â€”  18 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA2  â€”  11 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA20  â€”  9 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA22  â€”  33 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA23  â€”  0 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA24  â€”  16 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA25  â€”  40 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA4  â€”  0 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA5  â€”  0 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA7  â€”  33 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA8  â€”  40 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   OA9  â€”  39 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
# ============================================================
#   YA  (21 subjects)
# ============================================================
#
#   Y1  â€”  9 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y10  â€”  34 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y11  â€”  19 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y12  â€”  29 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y13  â€”  28 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y14  â€”  12 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y15  â€”  19 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y16  â€”  31 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y17  â€”  34 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y18  â€”  27 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y19  â€”  43 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y2  â€”  27 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y20  â€”  25 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y21  â€”  24 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y22  â€”  40 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y4  â€”  29 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y5  â€”  36 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y6  â€”  20 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y7  â€”  19 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y8  â€”  19 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed
#
#   Y9  â€”  21 segments
#     signals (50): achilles, addbrev, addlong, addmagDist, addmagIsch, addmagMid, addmagProx, ankle_fx, ankle_fy, ankle_fz, bflh, bfsh, cop_x, cop_y, cop_z, edl, ehl, fdl, fhl, gaslat, gasmed, glmax1, glmax2, glmax3, glmed1, glmed2, glmed3, glmin1, glmin2, glmin3, grac, grf_x, grf_y, grf_z, iliacus, knee_fx, knee_fy, knee_fz, perbrev, perlong, psoas, recfem, semimem, semiten, soleus, tibant, tibpost, vasint, vaslat, vasmed

# %% [markdown]
# ## Export OA and YA Segment Dicts

# %%
out_dir = '/Users/briankeller/Desktop/GRFMuscleModel/Old_Young_Walking_Data/'

with open(out_dir + 'Silder_OA_segs_normalized_filtered', 'wb') as f:
    pickle.dump(OA_segs, f)
print("Saved OA_segs_normalized_filtered")

with open(out_dir + 'Silder_YA_segs_normalized_filtered', 'wb') as f:
    pickle.dump(YA_segs, f)
print("Saved YA_segs_normalized_filtered")
# Out:
# Saved OA_segs_normalized_filtered
# Saved YA_segs_normalized_filtered
